# %% [markdown]
# # Necessary Libraries

# %%
import pandas as pd
import re
import string
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt   
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, GRU, Embedding, Dropout, Activation
from keras.layers import Bidirectional
from keras.models import Model
# from  matplotlib import pyplot as plt
from keras.utils.vis_utils import plot_model
from sklearn.metrics import confusion_matrix,f1_score, precision_score,recall_score

# %% [markdown]
# # Reading DataSet

# %%
data = pd.read_csv("spam(madeof).csv",encoding = "'latin'")

# %%
data.head()
# Out:
#      v1                                                 v2
# 0   ham  Subject: enron methanol ; meter # : 988291\nth...
# 1   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3  spam  Subject: photoshop , windows , office . cheap ...
# 4   ham  Subject: re : indian springs\r\nthis deal is t...

# %%
data["spam"] = data.v1
data["text"] = data.v2

# %% [markdown]
# # Splitting data

# %%
emails_train, emails_test, target_train, target_test = train_test_split(data.text, data.spam, test_size = 0.2)

# %%
data.info
# Out:
# <bound method DataFrame.info of         v1                                                 v2
# 0      ham  Subject: enron methanol ; meter # : 988291\nth...
# 1      ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2      ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3     spam  Subject: photoshop , windows , office . cheap ...
# 4      ham  Subject: re : indian springs\r\nthis deal is t...
# ...    ...                                                ...
# 5166   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169   ham  Subject: industrial worksheets for august 2000...
# 5170  spam  Subject: important online banking alert\r\ndea...
#
# [5171 rows x 2 columns]>

# %%
emails_train.shape
# Out:
# (4136,)

# %% [markdown]
# # Preprocessing

# %%
def remove_hyperlink(word):
    return  re.sub(r'http\S+', '', word)

def to_lower(word):
    result = word.lower()
    return result

def remove_number(word):
    result = re.sub(r'\d+', '', word)
    return result

def remove_punctuation(word):
    result = word.translate(str.maketrans(dict.fromkeys(string.punctuation)))
    return result

def remove_whitespace(word):
    result = word.strip()
    return result

def replace_newline(word):
    return word.replace('\n','')



def clean_up_pipeline(sentence):
    cleaning_utils = [remove_hyperlink,
                      replace_newline,
                      to_lower,
                      remove_number,
                      remove_punctuation,
                      remove_whitespace]
    for o in cleaning_utils:
        sentence = o(sentence)
    return sentence

x_train = [clean_up_pipeline(o) for o in emails_train]
x_test = [clean_up_pipeline(o) for o in emails_test]

x_train[0]

# %%
le = LabelEncoder()
train_y = le.fit_transform(target_train.values)
test_y = le.transform(target_test.values)

# %%
train_y
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %% [markdown]
# # Tokenize

# %%
## some config values 
embed_size = 100 # how big is each word vector
max_feature = 50000 # how many unique words to use (i.e num rows in embedding vector)
max_len = 2000 # max number of words in a question to use

# %%
tokenizer = Tokenizer(num_words=max_feature)

tokenizer.fit_on_texts(x_train)

x_train_features = np.array(tokenizer.texts_to_sequences(x_train))
x_test_features = np.array(tokenizer.texts_to_sequences(x_test))

x_train_features[0]

# %% [markdown]
# # Padding

# %%
x_train_features = pad_sequences(x_train_features,maxlen=max_len)
x_test_features = pad_sequences(x_test_features,maxlen=max_len)
x_train_features[0]
# Out:
# array([   0,    0,    0, ...,   72, 8435,  231], dtype=int32)

# %% [markdown]
# # Model

# %%
embedding_vecor_length = 32

# %% [markdown]
# #**LSTM**

# %%
# LSTM
model = tf.keras.Sequential()
model.add(Embedding(max_feature, embedding_vecor_length, input_length=max_len))
model.add(tf.keras.layers.LSTM(64))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2000, 32)          1600000
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                24832
# _________________________________________________________________
# dense (Dense)                (None, 16)                1040
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,625,889
# Trainable params: 1,625,889
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# LSTM
history = model.fit(x_train_features, train_y, batch_size=512, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 69s 9s/step - loss: 0.6868 - accuracy: 0.7022 - val_loss: 0.5670 - val_accuracy: 0.7041
# Epoch 2/20
# 7/7 [==============================] - 69s 9s/step - loss: 0.5079 - accuracy: 0.7159 - val_loss: 0.3819 - val_accuracy: 0.7295
# Epoch 3/20
# 7/7 [==============================] - 65s 9s/step - loss: 0.4356 - accuracy: 0.8006 - val_loss: 0.3400 - val_accuracy: 0.7826
# Epoch 4/20
# 7/7 [==============================] - 63s 9s/step - loss: 0.2877 - accuracy: 0.8810 - val_loss: 0.2681 - val_accuracy: 0.8986
# Epoch 5/20
# 7/7 [==============================] - 64s 9s/step - loss: 0.2564 - accuracy: 0.9681 - val_loss: 0.2518 - val_accuracy: 0.9372
# Epoch 6/20
# 7/7 [==============================] - 61s 9s/step - loss: 0.1999 - accuracy: 0.9878 - val_loss: 0.2253 - val_accuracy: 0.9529
# Epoch 7/20
# 7/7 [==============================] - 58s 8s/step - loss: 0.1702 - accuracy: 0.9952 - val_loss: 0.1807 - val_accuracy: 0.9734
# Epoch 8/20
# 7/7 [==============================] - 58s 8s/step - loss: 0.1295 - accuracy: 0.9982 - val_loss: 0.1586 - val_accuracy: 0.9553
# Epoch 9/20
# 7/7 [==============================] - 60s 9s/step - loss: 0.1145 - accuracy: 0.9854 - val_loss: 0.1763 - val_accuracy: 0.9686
# Epoch 10/20
# 7/7 [==============================] - 59s 9s/step - loss: 0.1086 - accuracy: 0.9922 - val_loss: 0.0948 - val_accuracy: 0.9795
# Epoch 11/20
# 7/7 [==============================] - 64s 9s/step - loss: 0.0472 - accuracy: 0.9966 - val_loss: 0.0701 - val_accuracy: 0.9819
# Epoch 12/20
# 7/7 [==============================] - 84s 13s/step - loss: 0.0561 - accuracy: 0.9864 - val_loss: 0.0819 - val_accuracy: 0.9819
# Epoch 13/20
# 7/7 [==============================] - 80s 12s/step - loss: 0.0313 - accuracy: 0.9998 - val_loss: 0.0597 - val_accuracy: 0.9819
# Epoch 14/20
# 7/7 [==============================] - 69s 9s/step - loss: 0.0208 - accuracy: 0.9979 - val_loss: 0.0531 - val_accuracy: 0.9843
# Epoch 15/20
# 7/7 [==============================] - 75s 11s/step - loss: 0.0142 - accuracy: 0.9987 - val_loss: 0.1233 - val_accuracy: 0.9505
# Epoch 16/20
# 7/7 [==============================] - 60s 9s/step - loss: 0.0342 - accuracy: 0.9915 - val_loss: 0.0543 - val_accuracy: 0.9855
# Epoch 17/20
# 7/7 [==============================] - 58s 8s/step - loss: 0.0126 - accuracy: 0.9998 - val_loss: 0.0546 - val_accuracy: 0.9783
# Epoch 18/20
# 7/7 [==============================] - 59s 8s/step - loss: 0.0079 - accuracy: 0.9987 - val_loss: 0.0552 - val_accuracy: 0.9807
# Epoch 19/20
# 7/7 [==============================] - 74s 11s/step - loss: 0.0060 - accuracy: 0.9993 - val_loss: 0.0919 - val_accuracy: 0.9650
# Epoch 20/20
# 7/7 [==============================] - 61s 9s/step - loss: 0.0097 - accuracy: 0.9985 - val_loss: 0.0591 - val_accuracy: 0.9807

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy of LSTM')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# #Confusion Matrix

# %%
y_predict  = [1 if o>0.5 else 0 for o in model.predict(x_test_features)]

# %%
cf_matrix =confusion_matrix(test_y,y_predict)

# %%
ax= plt.subplot()
sns.heatmap(cf_matrix, annot=True, ax = ax,cmap='Blues',fmt=''); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix of LSTM'); 
ax.xaxis.set_ticklabels(['Not Spam', 'Spam']); ax.yaxis.set_ticklabels(['Not Spam', 'Spam']);

# %%
tn, fp, fn, tp = confusion_matrix(test_y,y_predict).ravel()

# %%
print("Precision: {:.2f}%".format(100 * precision_score(test_y, y_predict)))
print("Recall: {:.2f}%".format(100 * recall_score(test_y, y_predict)))
print("F1 Score: {:.2f}%".format(100 * f1_score(test_y,y_predict)))
# Out:
# Precision: 28.48%
# Recall: 30.99%
# F1 Score: 29.68%

# %%
f1_score(test_y,y_predict)
# Out:
# 0.29679595278246207

# %% [markdown]
# #**Bi-LSTM**

# %%
# Bilstm
model = tf.keras.Sequential()
model.add(Embedding(max_feature, embedding_vecor_length, input_length=max_len))
model.add(Bidirectional(tf.keras.layers.LSTM(64)))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 2000, 32)          1600000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               49664
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                2064
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,651,745
# Trainable params: 1,651,745
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# BiLSTM
history = model.fit(x_train_features, train_y, batch_size=512, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 113s 16s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9807
# Epoch 2/20
# 7/7 [==============================] - 101s 14s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 0.9819
# Epoch 3/20
# 7/7 [==============================] - 103s 15s/step - loss: 9.1391e-04 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 0.9807
# Epoch 4/20
# 7/7 [==============================] - 98s 14s/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0715 - val_accuracy: 0.9722
# Epoch 5/20
# 7/7 [==============================] - 100s 14s/step - loss: 8.3298e-04 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9722
# Epoch 6/20
# 7/7 [==============================] - 101s 14s/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0904 - val_accuracy: 0.9734
# Epoch 7/20
# 7/7 [==============================] - 101s 14s/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0970 - val_accuracy: 0.9746
# Epoch 8/20
# 7/7 [==============================] - 99s 14s/step - loss: 6.5110e-04 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9746
# Epoch 9/20
# 7/7 [==============================] - 99s 14s/step - loss: 5.7622e-04 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 0.9771
# Epoch 10/20
# 7/7 [==============================] - 100s 14s/step - loss: 7.5656e-04 - accuracy: 0.9997 - val_loss: 0.1144 - val_accuracy: 0.9722
# Epoch 11/20
# 7/7 [==============================] - 98s 14s/step - loss: 0.4930 - accuracy: 0.9562 - val_loss: 0.1024 - val_accuracy: 0.9758
# Epoch 12/20
# 7/7 [==============================] - 99s 14s/step - loss: 7.8557e-04 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9734
# Epoch 13/20
# 7/7 [==============================] - 101s 14s/step - loss: 4.5009e-04 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9722
# Epoch 14/20
# 7/7 [==============================] - 102s 14s/step - loss: 9.1048e-04 - accuracy: 0.9997 - val_loss: 0.0975 - val_accuracy: 0.9734
# Epoch 15/20
# 7/7 [==============================] - 101s 14s/step - loss: 0.0488 - accuracy: 0.9876 - val_loss: 0.2486 - val_accuracy: 0.9408
# Epoch 16/20
# 7/7 [==============================] - 101s 14s/step - loss: 0.0104 - accuracy: 0.9955 - val_loss: 0.1812 - val_accuracy: 0.9589
# Epoch 17/20
# 7/7 [==============================] - 107s 15s/step - loss: 0.0493 - accuracy: 0.9804 - val_loss: 0.2376 - val_accuracy: 0.9360
# Epoch 18/20
# 7/7 [==============================] - 103s 14s/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.1694 - val_accuracy: 0.9517
# Epoch 19/20
# 7/7 [==============================] - 103s 15s/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.1696 - val_accuracy: 0.9577
# Epoch 20/20
# 7/7 [==============================] - 101s 14s/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.1669 - val_accuracy: 0.9614

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy of BiLSTM')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# #Confusion Matrix BiLSTM

# %%
y_predict  = [1 if o>0.5 else 0 for o in model.predict(x_test_features)]

# %%
cf_matrix =confusion_matrix(test_y,y_predict)

# %%
ax= plt.subplot()
sns.heatmap(cf_matrix, annot=True, ax = ax,cmap='Blues',fmt=''); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix of BiLSTM'); 
ax.xaxis.set_ticklabels(['Not Spam', 'Spam']); ax.yaxis.set_ticklabels(['Not Spam', 'Spam']);

# %%
tn, fp, fn, tp = confusion_matrix(test_y,y_predict).ravel()

# %%
print("Precision: {:.2f}%".format(100 * precision_score(test_y, y_predict)))
print("Recall: {:.2f}%".format(100 * recall_score(test_y, y_predict)))
print("F1 Score: {:.2f}%".format(100 * f1_score(test_y,y_predict)))
# Out:
# Precision: 93.36%
# Recall: 91.83%
# F1 Score: 92.59%

# %%
f1_score(test_y,y_predict)
# Out:
# 0.9258649093904449

# %% [markdown]
# #**GRU**

# %%
#GRU
model = tf.keras.Sequential()
model.add(Embedding(max_feature, embedding_vecor_length, input_length=max_len))
# model.add(GRU(units=64, dropout=0.1,recurrent_dropout=0.1))
model.add(tf.keras.layers.GRU(64))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 2000, 32)          1600000
# _________________________________________________________________
# gru (GRU)                    (None, 64)                18816
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,619,873
# Trainable params: 1,619,873
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# GRU
history = model.fit(x_train_features, train_y, batch_size=512, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 47s 6s/step - loss: 0.6740 - accuracy: 0.6919 - val_loss: 0.5881 - val_accuracy: 0.7041
# Epoch 2/20
# 7/7 [==============================] - 45s 6s/step - loss: 0.5434 - accuracy: 0.7096 - val_loss: 0.4898 - val_accuracy: 0.7186
# Epoch 3/20
# 7/7 [==============================] - 43s 6s/step - loss: 0.4089 - accuracy: 0.7458 - val_loss: 0.3367 - val_accuracy: 0.7657
# Epoch 4/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.2717 - accuracy: 0.8317 - val_loss: 0.2648 - val_accuracy: 0.8720
# Epoch 5/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.2129 - accuracy: 0.9544 - val_loss: 0.2289 - val_accuracy: 0.9094
# Epoch 6/20
# 7/7 [==============================] - 45s 6s/step - loss: 0.1795 - accuracy: 0.9855 - val_loss: 0.2270 - val_accuracy: 0.9408
# Epoch 7/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.1395 - accuracy: 0.9946 - val_loss: 0.1675 - val_accuracy: 0.9650
# Epoch 8/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.1009 - accuracy: 0.9971 - val_loss: 0.1461 - val_accuracy: 0.9734
# Epoch 9/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0717 - accuracy: 0.9965 - val_loss: 0.1135 - val_accuracy: 0.9758
# Epoch 10/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0523 - accuracy: 0.9952 - val_loss: 0.1292 - val_accuracy: 0.9589
# Epoch 11/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0494 - accuracy: 0.9928 - val_loss: 0.0671 - val_accuracy: 0.9758
# Epoch 12/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0183 - accuracy: 0.9985 - val_loss: 0.0679 - val_accuracy: 0.9734
# Epoch 13/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0141 - accuracy: 0.9982 - val_loss: 0.0925 - val_accuracy: 0.9589
# Epoch 14/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0245 - accuracy: 0.9940 - val_loss: 0.0677 - val_accuracy: 0.9746
# Epoch 15/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0117 - accuracy: 0.9995 - val_loss: 0.0575 - val_accuracy: 0.9783
# Epoch 16/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0074 - accuracy: 0.9995 - val_loss: 0.0525 - val_accuracy: 0.9771
# Epoch 17/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.0523 - val_accuracy: 0.9795
# Epoch 18/20
# 7/7 [==============================] - 45s 6s/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.0625 - val_accuracy: 0.9783
# Epoch 19/20
# 7/7 [==============================] - 44s 6s/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.0591 - val_accuracy: 0.9771
# Epoch 20/20
# 7/7 [==============================] - 46s 6s/step - loss: 0.0118 - accuracy: 0.9967 - val_loss: 0.0576 - val_accuracy: 0.9771

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy of GRU')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# #Confusion Matrix GRU

# %%
y_predict  = [1 if o>0.5 else 0 for o in model.predict(x_test_features)]

# %%
cf_matrix =confusion_matrix(test_y,y_predict)

# %%
ax= plt.subplot()
sns.heatmap(cf_matrix, annot=True, ax = ax,cmap='Blues',fmt=''); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels');
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Not Spam', 'Spam']); ax.yaxis.set_ticklabels(['Not Spam', 'Spam']);

# %%
tn, fp, fn, tp = confusion_matrix(test_y,y_predict).ravel()

# %%
print("Precision: {:.2f}%".format(100 * precision_score(test_y, y_predict)))
print("Recall: {:.2f}%".format(100 * recall_score(test_y, y_predict)))
print("F1 Score: {:.2f}%".format(100 * f1_score(test_y,y_predict)))
# Out:
# Precision: 93.57%
# Recall: 95.10%
# F1 Score: 94.33%

# %%
f1_score(test_y,y_predict)
# Out:
# 0.9432739059967585
